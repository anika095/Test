# %% [markdown]
# <a href="https://colab.research.google.com/github/anika095/Test/blob/main/NurunNaharAnikaFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#1
df= pd.DataFrame({'Name':['Alice', 'Bob'],'Age':[25,30]})
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
#2
#df.head()

# %%
#3
df.isnull().any()
# Out:
# Name    False
# Age     False
# dtype: bool

# %%
# Filter rows where 'Age' is greater than 25
filtered_df = df[df['Age'] > 25]
filtered_df
# Out:
#   Name  Age
# 1  Bob   30

# %%
# Remove duplicate rows based on all columns, keeping the first occurrence
df.drop_duplicates(keep='first', inplace=False)

# Remove duplicates based on 'Name' column, keeping the last occurrence
df.drop_duplicates(subset=['Name'], keep='last', inplace=False)

# Remove all occurrences of duplicate rows based on 'Age'
df.drop_duplicates(subset=['Age'], keep=False, inplace=False)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
#The merge() function in Pandas is used to combine two or more DataFrames
#based on the values of shared columns (keys)

# %%
# Sort by 'Age' in ascending order, then by 'Name' in descending order
sorted_df = df.sort_values(by=['Age', 'Name'], ascending=[False,True ])
sorted_df
# Out:
#     Name  Age
# 1    Bob   30
# 0  Alice   25

# %%
#Pandas primarily uses 'NaN' (Not a Number) to represent missing values in numeric columns (e.g., integers, floats).
#NaN' is a special floating-point value recognized by NumPy and Pandas

# %%
# Check for missing values in each column and display the count
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Name    0
# Age     0
# dtype: int64

# %%
#The fillna() function is used to fill missing values (NaN) in
#a Pandas DataFrame or Series with a specified value or method.

# %%
#ffill (forward fill): This method fills missing values with the previous non-missing value in the same column.
#bfill (backward fill): This method fills missing values with the next non-missing value in the same column

# %%
df1 = pd.DataFrame({
    'id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'score': [85, 92, 78, 88, 95]
})

df2 = pd.DataFrame({
    'id': [1, 2, 3, 4, 5],
    'age': [25, 30, 28, 22, 27],
    'city': ['New York', 'London', 'Paris', 'Tokyo', 'Sydney']
})

print(df1)
print(df2)
# Out:
#    id     name  score
# 0   1    Alice     85
# 1   2      Bob     92
# 2   3  Charlie     78
# 3   4    David     88
# 4   5      Eve     95
#    id  age      city
# 0   1   25  New York
# 1   2   30    London
# 2   3   28     Paris
# 3   4   22     Tokyo
# 4   5   27    Sydney

# %%
# Concatenate df1 and df2 using an inner join on 'id'
inner_joined = pd.concat([df1.set_index('id'), df2.set_index('id')], axis=1, join='inner')
inner_joined
# Out:
#        name  score  age      city
# id
# 1     Alice     85   25  New York
# 2       Bob     92   30    London
# 3   Charlie     78   28     Paris
# 4     David     88   22     Tokyo
# 5       Eve     95   27    Sydney

# %%
# Concatenate df1 and df2 using an outer join on 'id'
outer_joined = pd.concat([df1.set_index('id'), df2.set_index('id')], axis=1, join='outer')
outer_joined
# Out:
#        name  score  age      city
# id
# 1     Alice     85   25  New York
# 2       Bob     92   30    London
# 3   Charlie     78   28     Paris
# 4     David     88   22     Tokyo
# 5       Eve     95   27    Sydney

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns

# Your existing plot in the first subplot (ax1)
# ... (Your code for the first subplot goes here) ...

# Scatter plot of x vs. sin(x) in the second subplot (ax2)
ax2.scatter(x, np.sin(x))
ax2.set_xlabel('x')
ax2.set_ylabel('sin(x)')
ax2.set_title('Scatter Plot of x vs. sin(x)')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of x vs. sin(x)')

# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Access the data and target variables
X = iris.data
y = iris.target

# Optionally, create a Pandas DataFrame for easier handling
import pandas as pd
df = pd.DataFrame(data=X, columns=iris.feature_names)
df['target'] = y

df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import matplotlib.pyplot as plt

# Create a simple plot
plt.plot([1, 2, 3, 4], [5, 6, 7, 8])

# Save the plot with a higher resolution (300 dpi)
plt.savefig('my_high_res_plot.png')

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3]
y_values = [2, 4, 6]

plt.plot(x_values, y_values)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [5, 6, 7, 8]

plt.plot(x, y)       # Line plot only
plt.plot(x, y, 'o-') # Line plot with circular markers

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [5, 6, 7, 8]

plt.plot(x, y, color='red')  # Using color name
# Or
plt.plot(x, y, 'r')         # Using short color code
# Or
plt.plot(x, y, color='#FF0000') # Using hexadecimal color code

plt.show()

# %%
plt.plot(x, y, linestyle='dashed')
# Or, using the shorter alias:
plt.plot(x, y, ls='--')

# %%
#plt.plot(x, y, color='blue', linestyle='dotted')
# Or, using shorter aliases:
plt.plot(x, y, 'b:')

# %%
plt.plot(x, y, linewidth=3)  # Example: linewidth set to 3
# Or, using the shorter alias:
plt.plot(x, y, lw=3)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.plot(x, y)

# Set x-axis limits
plt.xlim(0, 10)

plt.show()

# %%
plt.ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %%
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 30, 40, 50]
y2 = [5, 15, 25, 35, 45]

plt.plot(x, y1, label='Time(s)')  # Label for the first line
plt.plot(x, y2, label='Frequency(Hz)')  # Label for the second line
plt.title("Wave")
plt.legend()  # Add the legend

plt.show()

# %%
#Q-9

y = [120, 200, 150, 90, 130]
x = ['Fruits', 'Vegetables', 'Dairy', 'Bakery', 'Snacks']
plt.bar(x, y)
plt.xlabel('Category')
plt.ylabel('Unit Sold')
plt.title('Monthly Sales Report')
plt.show()

# %%
units_sold = [120, 200, 150, 90, 130]
avg_price = [2.5, 1.5, 2.0, 1.8, 3.0]

plt.scatter(units_sold, avg_price)
plt.title('Units Sold vs. Average Price')
plt.xlabel('Units Sold')
plt.ylabel('Average Price ($)')

plt.show()

# %%
customer_ratings = [4.5, 4.2, 4.0, 3.8, 4.1]

plt.hist(customer_ratings)
plt.title('Distribution of Customer Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')

plt.show()

# %%
categories = ['Fruits', 'Vegetables', 'Dairy', 'Bakery', 'Snacks']
units_sold = [120, 200, 150, 90, 130]

plt.pie(units_sold, labels=categories, autopct='%1.1f%%')
plt.title('Percentage of Units Sold by Category')
plt.legend(title='Categories')  # Add a legend for category names

plt.show()

# %%
customer_ratings = [4.5, 4.2, 4.0, 3.8, 4.1]

plt.boxplot(customer_ratings)
plt.title('Distribution of Customer Ratings')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
#8
import pandas as pd
data= {'Product Name': ['Pen','Notebook','Eraser','Marker','Highlighter'], 'Price':[1.5, None, 0.5, 1.2, None],
    'Discount': [10, 5, None, 15, None]
}
Products_df = pd.DataFrame(data)
Products_df
# Out:
#   Product Name  Price  Discount
# 0          Pen    1.5      10.0
# 1     Notebook    NaN       5.0
# 2       Eraser    0.5       NaN
# 3       Marker    1.2      15.0
# 4  Highlighter    NaN       NaN

# %%
pd.isnull(Products_df)
# Out:
#    Product Name  Price  Discount
# 0         False  False     False
# 1         False   True     False
# 2         False  False      True
# 3         False  False     False
# 4         False   True      True

# %%
pd.isnull(Products_df).sum()
# Out:
# Product Name    0
# Price           2
# Discount        2
# dtype: int64

# %%
pd.fillna(0, inplace=True)
Products_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-68cc1ee72cac> in <cell line: 1>()
# ----> 1 pd.fillna(0, inplace=True)
#       2 Products_df
#
# AttributeError: module 'pandas' has no attribute 'fillna'

# %%
#6
import pandas as pd

# Product data with missing values
data = {
    'Product Name': ['Pen', 'Notebook', 'Eraser', 'Marker', 'Highlighter'],
    'Price': [1.5, None, 0.5, 1.2, None],
    'Discount': [10, 5, None, 15, None]
}
products_df = pd.DataFrame(data)

# Count missing values in each column
missing_values = products_df.isnull().sum()

print(missing_values)
# Out:
# Product Name    0
# Price           2
# Discount        2
# dtype: int64

# %%
products_df['Price'].fillna(1.0, inplace=True)
# Out:
# <ipython-input-47-fa9e5549efd4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df['Price'].fillna(1.0, inplace=True)

# %%
median_discount = products_df['Discount'].median()
products_df['Discount']=products_df['Discount'].fillna(median_discount, inplace=True)
products_df
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# <ipython-input-63-6a79c27a87a1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df['Discount']=products_df['Discount'].fillna(median_discount, inplace=True)
# ...

# %%
#7
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Department': ['HR', 'IT', 'Finance', None, 'Marketing'],
    'Years of Experience': [5, None, 8, 6, None]
}
employees_df = pd.DataFrame(data)
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 3    David       None                  6.0
# 4      Eva  Marketing                  NaN

# %%
MV = employees_df.isnull().sum()
MV
# Out:
# Name                   0
# Department             1
# Years of Experience    2
# dtype: int64

# %%
employees_df.dropna(subset=['Department'], inplace=True)
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 4      Eva  Marketing                  NaN

# %%
#df[col] = df[col].method(value)
employees_df['Years of Experience'] = employees_df['Years of Experience'].fillna(employees_df['Years of Experience'].mean())
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  6.5
# 2  Charlie    Finance                  8.0
# 4      Eva  Marketing                  6.5

# %%
#5
import pandas as pd

data = {
    'Product Name': ['Pen', 'Notebook', 'Eraser'],
    'Price': [1.5, 3.0, 0.5],
    'Stock': [100, 50, 200]
}

products_df = pd.DataFrame(data)

print(products_df)
# Out:
#   Product Name  Price  Stock
# 0          Pen    1.5    100
# 1     Notebook    3.0     50
# 2       Eraser    0.5    200

# %%
notebook_price = products_df.loc[products_df['Product Name'] == 'Notebook', 'Price'].iloc[0]

print(notebook_price)
# Out:
# 3.0

# %%
#4
import pandas as pd

student_data = [
    {'Name': 'Alice', 'Age': 25, 'Score': 85},
    {'Name': 'Bob', 'Age': 30, 'Score': 92},
    {'Name': 'Charlie', 'Age': 28, 'Score': 78},
    {'Name': 'David', 'Age': 22, 'Score': 88},
    {'Name': 'Eve', 'Age': 27, 'Score': 95}
]

students_df = pd.DataFrame(student_data)

print(students_df)
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     92
# 2  Charlie   28     78
# 3    David   22     88
# 4      Eve   27     95

# %%
scores = students_df['Score'].to_numpy()

print(scores)
# Out:
# [85 92 78 88 95]

# %%
import pandas as pd

# %%
rainfall_data = pd.Series([78, 92, 56, 89], index=['January', 'February', 'March', 'April'])

# %%
february_rainfall = rainfall_data['February']
february_rainfall
# Out:
# 92

# %%
#3
# Load dataset
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['species'] = data.target
print(df)
# Introduce missing values
np.random.seed(0)
missing_indices = np.random.choice(df.index, size=5, replace=False)
df.loc[missing_indices, 'sepal length (cm)'] = np.nan
df.loc[missing_indices, 'petal length (cm)'] = np.nan

# Fill missing values with mean
df.fillna(df.mean(), inplace=True)
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

X = df[data.feature_names]
y = df['species']

# Initialize Decision tree and KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
model = DecisionTreeClassifier(random_state=42)

# split the data with 50% in each set
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5,
                                   random_state=0)

# fit the model on one set of data
model.fit(X_train, y_train)

# evaluate the model on the second set of data
y_pred = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Precision: ", precision_score(y_test, y_pred, average='macro'))
print("Recall: ", recall_score(y_test, y_pred, average='macro'))
print("F1 score: ", f1_score(y_test, y_pred, average='macro'))

# Cross-validation scores
accuracy_scores = cross_val_score(model, X, y, cv=kf, scoring='accuracy')
print("Cross validation scores: ", accuracy_scores)
# Out:
# Accuracy:  0.9333333333333333
# Precision:  0.9451032059727712
# Recall:  0.9293650793650793
# F1 score:  0.935601711133626
# Cross validation scores:  [1.         0.96666667 0.86666667 0.93333333 0.93333333]

# %%
# Plot sine and cosine in the first subplot (ax1)
ax1.plot(x, sine_values, color='blue', linestyle='-', label='Sine')
ax1.plot(x, cosine_values, color='orange', linestyle='--', label='Cosine')

# Set axes limits
ax1.set_xlim(0, 10)
ax1.set_ylim(-1.5, 1.5)

# Add labels, title, and legend
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('Sine and Cosine Functions')
ax1.legend()

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    'max_depth': [3, 5, 7, None],
    'min_samples_split': [2, 5, 10]
}

# Grid Search
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=kf, scoring='accuracy')
grid_search.fit(X_train, y_train)

print("Best parameters from Grid Search:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)
# Out:
# Best parameters from Grid Search: {'max_depth': 5, 'min_samples_split': 2}
# Best cross-validation accuracy: 0.9333333333333332

# %%
import numpy as np
x = np.linspace(0, 10, 100)
fig = plt.figure()

plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), '-', color = 'blue')
plt.plot(x, np.cos(x), '--', color = 'orange')
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

plt.subplot(2, 1, 2)
plt.errorbar(x, np.sin(x), yerr=0.4, fmt='-r');

fig.savefig('trigonometric_plots.png')

plt.show()
