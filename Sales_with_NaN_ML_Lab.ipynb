# %% [markdown]
# <a href="https://colab.research.google.com/github/anika095/Test/blob/main/Sales_with_NaN_ML_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/Sales_with_NaNs_v1.3.csv')
df
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4           NaN       High Value    229.685623          NaN
# ...         ...              ...           ...          ...
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# ...

# %%
df.columns
# Out:
# Index(['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
#        'Customer_Satisfaction_Before', 'Customer_Satisfaction_After',
#        'Purchase_Made'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %%
df.head(10)
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
# 5  Treatment              NaN    135.573003   218.559988
# 6    Control       High Value    191.713918   222.409356
# 7    Control        Low Value    173.752555   213.168232
# 8        NaN       High Value    208.308577   248.178830
# 9  Treatment       High Value    235.071493   352.756872
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# ...

# %%
df.tail()
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 9995                     88.438776                    98.418593           NaN
# 9996                     92.261537                   100.000000           NaN
# 9997                     55.915870                          NaN            No
# 9998                     66.082462                    81.274030            No
# 9999                     55.692277                    65.288480           Yes

# %%
df.tail()
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 9995                     88.438776                    98.418593           NaN
# 9996                     92.261537                   100.000000           NaN
# 9997                     55.915870                          NaN            No
# 9998                     66.082462                    81.274030            No
# 9999                     55.692277                    65.288480           Yes

# %%
df.describe()
# Out:
#        Sales_Before  Sales_After  Customer_Satisfaction_Before  \
# count   8478.000000  9233.000000                   8330.000000
# mean     203.716998   280.457952                     70.252076
# std       55.273059    85.659543                     16.957010
# min       24.852966    32.414352                     22.202441
# 25%      166.629232   221.436990                     56.365513
# 50%      203.323607   273.129170                     69.490898
# 75%      238.809147   332.570108                     83.426798
# max      545.422547   818.219997                    100.000000
#
#        Customer_Satisfaction_After
# count                  8360.000000
# mean                     73.872593
# std                      18.128351
# min                      18.224938
# 25%                      59.925030
# 50%                      73.844594
# 75%                      90.044365
# max                     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Group                         8599 non-null   object
#  1   Customer_Segment              8034 non-null   object
#  2   Sales_Before                  8478 non-null   float64
#  3   Sales_After                   9233 non-null   float64
#  4   Customer_Satisfaction_Before  8330 non-null   float64
#  5   Customer_Satisfaction_After   8360 non-null   float64
#  6   Purchase_Made                 9195 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df.isnull()
# Out:
#       Group  Customer_Segment  Sales_Before  Sales_After  \
# 0     False             False         False        False
# 1     False             False         False        False
# 2     False             False         False        False
# 3     False             False         False        False
# 4      True             False         False         True
# ...     ...               ...           ...          ...
# 9995  False              True         False        False
# 9996  False             False         False        False
# 9997  False             False         False        False
# 9998  False             False          True        False
# 9999  False             False          True        False
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After  Purchase_Made
# 0                            False                         True          False
# 1                            False                        False          False
# ...

# %%
df.isnull().sum()
# Out:
# Group                           1401
# Customer_Segment                1966
# Sales_Before                    1522
# Sales_After                      767
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                    805
# dtype: int64

# %%
df.shape
# Out:
# (10000, 7)

# %%
df2 = df.dropna()
df2.shape
# Out:
# (3412, 7)

# %%
df3 = df.dropna(axis = 1)
df3.shape
# Out:
# (10000, 0)

# %%
df.dropna(how = 'any')
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 6       Control       High Value    191.713918   222.409356
# 9     Treatment       High Value    235.071493   352.756872
# ...         ...              ...           ...          ...
# 9984  Treatment       High Value    234.970184   360.308311
# 9985  Treatment        Low Value    190.882210   300.525743
# 9987  Treatment     Medium Value    164.011355   247.268535
# 9989    Control     Medium Value    109.386552   145.054224
# 9992  Treatment     Medium Value    209.913990   320.791145
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 1                       100.000000                   100.000000           Yes
# 2                        98.780735                   100.000000            No
# ...

# %%
df.dropna(how = 'all')
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4           NaN       High Value    229.685623          NaN
# ...         ...              ...           ...          ...
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# ...

# %%
df.fillna(0)
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4             0       High Value    229.685623     0.000000
# ...         ...              ...           ...          ...
# 9995  Treatment                0    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value      0.000000   431.974901
# 9999    Control        Low Value      0.000000   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                        74.684767                     0.000000            No
# 1                       100.000000                   100.000000           Yes
# ...

# %%
df.replace(34, 10000)
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4           NaN       High Value    229.685623          NaN
# ...         ...              ...           ...          ...
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# ...

# %%
df.loc[1]
# Out:
# Group                            Treatment
# Customer_Segment                High Value
# Sales_Before                    246.862114
# Sales_After                     381.337555
# Customer_Satisfaction_Before         100.0
# Customer_Satisfaction_After          100.0
# Purchase_Made                          Yes
# Name: 1, dtype: object

# %%
df.loc[5]
# Out:
# Group                            Treatment
# Customer_Segment                       NaN
# Sales_Before                    135.573003
# Sales_After                     218.559988
# Customer_Satisfaction_Before     58.075342
# Customer_Satisfaction_After      69.404918
# Purchase_Made                           No
# Name: 5, dtype: object

# %%
df.loc[[5,6,7,8]]
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 5  Treatment              NaN    135.573003   218.559988
# 6    Control       High Value    191.713918   222.409356
# 7    Control        Low Value    173.752555   213.168232
# 8        NaN       High Value    208.308577   248.178830
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 5                     58.075342                    69.404918            No
# 6                     89.967827                    85.120975           Yes
# 7                     66.984711                    67.881558           NaN
# 8                     95.366670                    84.790294           Yes

# %%
df.loc[5:15]
# Out:
#         Group Customer_Segment  Sales_Before  Sales_After  \
# 5   Treatment              NaN    135.573003   218.559988
# 6     Control       High Value    191.713918   222.409356
# 7     Control        Low Value    173.752555   213.168232
# 8         NaN       High Value    208.308577   248.178830
# 9   Treatment       High Value    235.071493   352.756872
# 10    Control        Low Value    139.931539   170.238396
# 11    Control       High Value           NaN   333.064972
# 12    Control              NaN    211.834937   254.843912
# 13    Control       High Value    217.776013   259.989624
# 14        NaN     Medium Value    173.183445   284.924299
# 15    Control        Low Value    188.338963   232.582486
#
#     Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 5                      58.075342                    69.404918            No
# 6                      89.967827                    85.120975           Yes
# ...

# %%
df.iloc[[0,1,2,3]]
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes

# %%
df.loc[5:15, 'Customer_Segment']
# Out:
# 5              NaN
# 6       High Value
# 7        Low Value
# 8       High Value
# 9       High Value
# 10       Low Value
# 11      High Value
# 12             NaN
# 13      High Value
# 14    Medium Value
# 15       Low Value
# Name: Customer_Segment, dtype: object

# %%
df.loc[df['Customer_Satisfaction_Before']<50]
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 3       Control     Medium Value    192.126708   229.278031
# 27    Treatment        Low Value    213.222288   341.428156
# 33    Treatment       High Value           NaN   132.287222
# 37          NaN     Medium Value    203.846220   243.766889
# 53    Treatment       High Value    240.138137   376.409945
# ...         ...              ...           ...          ...
# 9933        NaN     Medium Value    250.692652   398.408162
# 9934    Control              NaN    171.884144   209.647005
# 9953    Control        Low Value    117.090003   131.348135
# 9974    Control        Low Value           NaN   219.120824
# 9981        NaN        Low Value    103.570047   154.528708
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 3                        49.333766                    39.811841           Yes
# 27                       45.399793                    46.476301            No
# ...

# %%
df.iloc[0]
# Out:
# Group                              Control
# Customer_Segment                High Value
# Sales_Before                    240.548359
# Sales_After                     300.007568
# Customer_Satisfaction_Before     74.684767
# Customer_Satisfaction_After            NaN
# Purchase_Made                           No
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#      Group Customer_Segment  Sales_Before  Sales_After  \
# 0  Control       High Value    240.548359   300.007568
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No

# %%
df.iloc[[0,1,2,3]]
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes

# %%
df.iloc[:,0]
# Out:
# 0         Control
# 1       Treatment
# 2         Control
# 3         Control
# 4             NaN
#           ...
# 9995    Treatment
# 9996      Control
# 9997    Treatment
# 9998    Treatment
# 9999      Control
# Name: Group, Length: 10000, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0         High Value
# 1         High Value
# 2         High Value
# 3       Medium Value
# 4         High Value
#             ...
# 9995             NaN
# 9996      High Value
# 9997       Low Value
# 9998    Medium Value
# 9999       Low Value
# Name: Customer_Segment, Length: 10000, dtype: object

# %%
df.iloc[0:5, 1]
# Out:
# 0      High Value
# 1      High Value
# 2      High Value
# 3    Medium Value
# 4      High Value
# Name: Customer_Segment, dtype: object

# %%
df.iloc[0:5, 1:4]
# Out:
#   Customer_Segment  Sales_Before  Sales_After
# 0       High Value    240.548359   300.007568
# 1       High Value    246.862114   381.337555
# 2       High Value    156.978084   179.330464
# 3     Medium Value    192.126708   229.278031
# 4       High Value    229.685623          NaN

# %%
df.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %%
br_grp = df.groupby(by = 'Sales_Before')
br_grp

# %%
br_grp.groups
# Out:
# {24.85296575372195: [5504], 31.024395717144664: [6112], 36.33837259684434: [4171], 36.72470518: [6491], 42.02982644514369: [4977], 46.309934899355845: [4481], 47.71999152099225: [1603], 49.78371495602873: [5226], 50.90156615517605: [4852], 51.35872919941765: [8110], 51.39478078665196: [5518], 51.69559029860352: [4457], 52.65764275076749: [8000], 53.76418067031987: [4681], 53.94198374045657: [3914], 53.9485105510776: [5098], 54.4626351441388: [5864], 54.79291069162856: [5965], 54.91769260779564: [3325], 55.820722526544536: [7792], 57.20688314159366: [4490], 58.691600837080415: [486], 58.76286547260897: [4606], 59.510943901028455: [4024], 59.542426304219376: [7506], 60.12840820490236: [6550], 60.17795828518378: [3983], 60.63590375209254: [5870], 61.73196839975687: [4230], 63.42774495173367: [5131], 63.54905801321356: [4607], 63.66665684786928: [7085], 64.03958727047979: [4945], 64.45377258547747: [1196], 64.52034322235386: [6152], 64.68619425282363: [5307], 65.08002112442301: [3967], 6
# ...

# %%
new_grp = df.groupby(by = ['Sales_Before', 'Sales_After'])
new_grp.groups
# Out:
# {(24.85296575372195, 32.414352282538246): [5504], (31.024395717144664, 35.50054586300189): [6112], (36.72470518, 47.86945901): [6491], (49.78371495602873, 69.74533358767307): [5226], (nan, 325.1178512605295): [5483], (51.35872919941765, 77.71757335913125): [8110], (51.39478078665196, 84.25779161964032): [5518], (52.65764275076749, 69.17573666099986): [8000], (53.9485105510776, 85.19050359678528): [5098], (54.4626351441388, 66.55051053049502): [5864], (54.79291069162856, 70.57950613834234): [5965], (55.820722526544536, 73.68819740991222): [7792], (59.542426304219376, 78.74588778784177): [7506], (60.12840820490236, 53.42317329100128): [6550], (60.63590375209254, 77.18538173509188): [5870], (63.42774495173367, 73.79279581456765): [5131], (63.66665684786928, 109.94925474991685): [7085], (64.52034322235386, 83.73656860802106): [6152], (64.68619425282363, 79.75025743): [5307], (65.13694654851096, 91.87476685129243): [9733], (67.39883933970499, 70.43395920401541): [6170], (67.46756439673499
# ...

# %%
for group, data_frame in new_grp:
    print(group)
    print(data_frame)
# Out:
# Streaming output truncated to the last 5000 lines.
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 4037                           NaN                    74.981519           NaN
# (272.1376044978227, 317.8550865773177)
#         Group Customer_Segment  Sales_Before  Sales_After  \
# 2324  Control        Low Value    272.137604   317.855087
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 2324                     47.032868                    54.402427            No
# (272.1419853372516, 443.2772220051848)
#      Group Customer_Segment  Sales_Before  Sales_After  \
# 3652   NaN       High Value    272.141985   443.277222
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 3652                     92.790108                    97.281053            No
# (272.1860012584151, 323.0428862354369)
#         Group Customer_Segment  Sales_Before  Sales_After  \
# ...

# %%
br_grp = df.groupby(by = 'Sales_Before')
br_grp

# %%
df1 = pd.DataFrame({'Name':['A','B','C','D','E'], 'Age':[34,67,34,89,12]})
df1
# Out:
#   Name  Age
# 0    A   34
# 1    B   67
# 2    C   34
# 3    D   89
# 4    E   12

# %%
df2 = pd.DataFrame({'Name':['A','B','C','D','E'],'Serial':[78,33,39,81,90]})
df2
# Out:
#   Name  Serial
# 0    A      78
# 1    B      33
# 2    C      39
# 3    D      81
# 4    E      90

# %%
pd.merge(df1, df2, on = 'Name')
# Out:
#   Name  Age  Serial
# 0    A   34      78
# 1    B   67      33
# 2    C   34      39
# 3    D   89      81
# 4    E   12      90

# %%
pd.merge(df1, df2)
# Out:
#   Name  Age  Serial
# 0    A   34      78
# 1    B   67      33
# 2    C   34      39
# 3    D   89      81
# 4    E   12      90

# %%
df.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x= np.arange(1,11)
y= 2*x
plt.plot(x,y)
plt.show()

# %%
plt.title('X vs Y')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y, color='g' , linestyle=':' , linewidth=5)
plt.show()

# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = np.random.randn(1000)

# %%
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, edgecolor='black')
plt.title('Histogram with Matplotlib')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, kde=True)
plt.title('Histogram with Seaborn')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = np.random.randn(1000)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, edgecolor='black')
plt.title('Histogram with Matplotlib')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, kde=True)
plt.title('Histogram with Seaborn')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
