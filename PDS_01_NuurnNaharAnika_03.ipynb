# %% [markdown]
# <a href="https://colab.research.google.com/github/anika095/Test/blob/main/PDS_01_NuurnNaharAnika_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a)fig.savefig('Plot_image.png')

# %% [markdown]
# c)df.ylim(-10,10)

# %% [markdown]
# d)pd.marge(df1,df2, on='ID')

# %% [markdown]
# f)plt.plot(x,y, 'b:')

# %% [markdown]
# h)x=[1,2,3]
# y=[2,6,4]
# plt.plot(x,y)
# plt.show()

# %%
import pandas as pd

# %%
#1

import numpy as np
import pandas as pd

rainfall_data = pd.Series([80,65,90,78,105,120], index=['January', 'February', 'March', 'April','May','June'])
rainfall_data
# Out:
# January      80
# February     65
# March        90
# April        78
# May         105
# June        120
# dtype: int64

# %%
february_rainfall = rainfall_data['May']
february_rainfall
# Out:
# 105

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Department': ['HR', 'IT', 'Finance', None, 'Marketing'],
    'Years of Experience': [5, None, 8, 6, None]
}
employees_df = pd.DataFrame(data)
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 3    David       None                  6.0
# 4      Eva  Marketing                  NaN

# %%
MV = employees_df.isnull().sum()
MV
# Out:
# Name                   0
# Department             1
# Years of Experience    2
# dtype: int64

# %%
employees_df.dropna(subset=['Department'], inplace=True)
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 4      Eva  Marketing                  NaN

# %%
employees_df['Years of Experience'] = employees_df['Years of Experience'].fillna(employees_df['Years of Experience'].mean())
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  6.5
# 2  Charlie    Finance                  8.0
# 4      Eva  Marketing                  6.5

# %%
df1 = pd.DataFrame({'Name':['Anika','FAiza','Alif'], 'Age':[10,20,30],'Score':[70,80,60]})
df2 = pd.DataFrame({'Name':['Pallab','Pamel','prohor'],
                    'Age':[23,22,21],
                    'Score':[100,90,80]})

print(df1)
print(df2)
# Out:
#     Name  Age  Score
# 0  Anika   10     70
# 1  FAiza   20     80
# 2   Alif   30     60
#      Name  Age  Score
# 0  Pallab   23    100
# 1   Pamel   22     90
# 2  prohor   21     80

# %%
pd.concat([df1,df2], axis=0)
# Out:
#      Name  Age  Score
# 0   Anika   10     70
# 1   FAiza   20     80
# 2    Alif   30     60
# 0  Pallab   23    100
# 1   Pamel   22     90
# 2  prohor   21     80

# %%
a=[1,2,3]
b=[4,5,6]

A=np.concatenate((a,b))
A
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
df1 = pd.DataFrame({
    'Id': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Score': [85, 92, 78, 88, 95]
})

df2 = pd.DataFrame({
    'Id': [1, 2, 3, 4, 5],
    'Age': [25, 30, 28, 22, 27],
    'City': ['New York', 'London', 'Paris', 'Tokyo', 'Sydney']
})

print(df1)
print(df2)
# Out:
#    Id     Name  Score
# 0   1    Alice     85
# 1   2      Bob     92
# 2   3  Charlie     78
# 3   4    David     88
# 4   5      Eve     95
#    Id  Age      City
# 0   1   25  New York
# 1   2   30    London
# 2   3   28     Paris
# 3   4   22     Tokyo
# 4   5   27    Sydney

# %%
inner_joined = pd.concat([df1,df2],join='inner')
inner_joined
# Out:
#    Id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
outter_joined = pd.concat([df1,df2], join='outer')
outter_joined
# Out:
#    Id     Name  Score   Age      City
# 0   1    Alice   85.0   NaN       NaN
# 1   2      Bob   92.0   NaN       NaN
# 2   3  Charlie   78.0   NaN       NaN
# 3   4    David   88.0   NaN       NaN
# 4   5      Eve   95.0   NaN       NaN
# 0   1      NaN    NaN  25.0  New York
# 1   2      NaN    NaN  30.0    London
# 2   3      NaN    NaN  28.0     Paris
# 3   4      NaN    NaN  22.0     Tokyo
# 4   5      NaN    NaN  27.0    Sydney

# %%
M = pd.merge(df1,df2, on='Id')
M
# Out:
#    Id     Name  Score  Age      City
# 0   1    Alice     85   25  New York
# 1   2      Bob     92   30    London
# 2   3  Charlie     78   28     Paris
# 3   4    David     88   22     Tokyo
# 4   5      Eve     95   27    Sydney

# %%
df1 = pd.DataFrame({
    'Product': ['Apple', 'B', 'C', 'Dd', 'E'],
    'Region': ['North', 'South', 'East', 'West', 'G'],
    'Sales': [85, 92, 78, 88, 95],
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']
})

df1
# Out:
#   Product Region  Sales        Date
# 0   Apple  North     85  2023-01-01
# 1       B  South     92  2023-01-02
# 2       C   East     78  2023-01-03
# 3      Dd   West     88  2023-01-04
# 4       E      G     95  2023-01-05

# %%
T=df1.groupby('Region')['Sales'].sum().reset_index()
T
A=df1.groupby('Product')['Sales'].mean().reset_index()
A
# Out:
#   Product  Sales
# 0   Apple   85.0
# 1       B   92.0
# 2       C   78.0
# 3      Dd   88.0
# 4       E   95.0

# %%
import numpy as np
x = np.linspace(0, 10, 100)
fig = plt.figure()

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))


plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), 'o', color = 'blue')
plt.plot(x, np.cos(x), '--', color = 'orange')
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

plt.subplot(2, 1, 2)

plt.errorbar(x, np.cos(x),yerr=0.3,marker='o',color='red', fmt='-r', label='cos(x) with error');
plt.legend()

fig.savefig('trigonometric_plots.png')

plt.show()
# Out:
# <ipython-input-69-96e1285daefd>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-r" (-> color='r'). The keyword argument will take precedence.
#   plt.errorbar(x, np.cos(x),yerr=0.3,marker='o',color='red', fmt='-r', label='cos(x) with error');
